# %% [markdown]
# # Preprocessing of airports.csv

# %%
import numpy as np
import pandas as pd

# %%
# load data
airports = pd.read_csv('../data/raw/airports.csv', dtype='str')
airports
# Out:
#                                            name continent iso_country  \
# 0                              Brussels Airport        EU          BE
# 1                     Frankfurt am Main Airport        EU          DE
# 2                           DÃ¼sseldorf Airport        EU          DE
# 3                                Munich Airport        EU          DE
# 4                             Stuttgart Airport        EU          DE
# 5                          Berlin-Tegel Airport        EU          DE
# 6                       Helsinki Vantaa Airport        EU          FI
# 7                            Manchester Airport        EU          GB
# 8                       London Heathrow Airport        EU          GB
# 9                    Amsterdam Airport Schiphol        EU          NL
# 10                               Dublin Airport        EU          IE
# 11                   Copenhagen Kastrup Airport        EU          DK
# ...

# %%
# save processed data
airports.to_csv('../data/processed/airports.csv')
